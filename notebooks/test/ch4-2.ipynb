# %% [markdown]
# 数据的一些预处理。pytorch/chapter_preliminaries/pandas.ipynb

# %%
import os
# 创建了一个人工数据集，并将其保存在一个CSV文件中。数据集包含三个字段：NumRooms（房间数量）、Alley（巷道类型）和Price（价格）。其中，NumRooms和Alley字段包含一些缺失值（用NA表示）。
os.makedirs(os.path.join('..', 'data'), exist_ok=True)
data_file = os.path.join('..', 'data', 'house_tiny.csv')
with open(data_file, 'w') as f:
    f.write('NumRooms,Alley,Price\n')  # 列名
    f.write('NA,Pave,127500\n')  # 每行表示一个数据样本
    f.write('2,NA,106000\n')
    f.write('4,NA,178100\n')
    f.write('NA,NA,140000\n')

# %%
# 读取CSV文件并打印数据
import pandas as pd

data = pd.read_csv(data_file)
print(data)
# Out:
#    NumRooms Alley   Price
# 0       NaN  Pave  127500
# 1       2.0   NaN  106000
# 2       4.0   NaN  178100
# 3       NaN   NaN  140000

# %%
inputs, outputs = data.iloc[:, 0], data.iloc[:, 2] # alley列是文本数据，新版的mean函数无法处理文本数据，因此我们只对数值数据进行处理
inputs = inputs.fillna(inputs.mean())
print(inputs)
# Out:
# 0    3.0
# 1    2.0
# 2    4.0
# 3    3.0
# Name: NumRooms, dtype: float64
